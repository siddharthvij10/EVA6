# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms


import warnings
warnings.filterwarnings("ignore")

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        drop_out_val = 0.05 # 0.05
        self.convblock1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=8, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(8),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28, rc-3

        self.convblock2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=8, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(8),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28, rc-5

        self.pool1 = nn.MaxPool2d(2, 2) # output_size = 12

        self.convblock3 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28

        self.convblock4 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=16, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28

        self.pool2 = nn.MaxPool2d(2, 2) # output_size = 14
        self.convblock100 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=8, kernel_size=(1, 1), padding=0, bias=False),
            # nn.ReLU(),
            # nn.Dropout(p=drop_out_val)
        ) # output_size = 14

        self.convblock5 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3, 3), padding=0, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 12

        self.convblock6 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=16, kernel_size=(3, 3), padding=0, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 10

        self.gap = nn.Sequential(nn.AvgPool2d(3)) # output_size = 1
        self.fc = nn.Linear(16, 10)  # 1*1*32 | 10


    def forward(self, x):
        # Adding drop out reduces the accuracy a bit
        x = self.convblock1(x)
        x = self.convblock2(x)
        x = self.pool1(x)
        x = self.convblock3(x)
        x = self.convblock4(x)
        x = self.pool2(x)
        x = self.convblock100(x)
        x = self.convblock5(x)
        x = self.convblock6(x)
        x = self.gap(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return F.log_softmax(x)

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net().to(device)
summary(model, input_size=(1, 28, 28))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              72
#               ReLU-2            [-1, 8, 28, 28]               0
#        BatchNorm2d-3            [-1, 8, 28, 28]              16
#            Dropout-4            [-1, 8, 28, 28]               0
#             Conv2d-5            [-1, 8, 28, 28]             576
#               ReLU-6            [-1, 8, 28, 28]               0
#        BatchNorm2d-7            [-1, 8, 28, 28]              16
#            Dropout-8            [-1, 8, 28, 28]               0
#          MaxPool2d-9            [-1, 8, 14, 14]               0
#            Conv2d-10           [-1, 16, 14, 14]           1,152
#              ReLU-11           [-1, 16, 14, 14]               0
#       BatchNorm2d-12           [-1, 16, 14, 14]              32
#           Dropout-13           [-1, 16, 14, 14]               0
#            Conv2d-14           [-1, 16, 14, 14]           2,304
#              ReLU-15           [-1, 16, 14, 14]               0
#       BatchNorm2d-16           [-1, 16, 14, 14]              32
#           Dropout-17           [-1, 16, 14, 14]               0
#         MaxPool2d-18             [-1, 16, 7, 7]               0
#            Conv2d-19              [-1, 8, 7, 7]             128
#            Conv2d-20             [-1, 16, 5, 5]           1,152
#              ReLU-21             [-1, 16, 5, 5]               0
#       BatchNorm2d-22             [-1, 16, 5, 5]              32
#           Dropout-23             [-1, 16, 5, 5]               0
#            Conv2d-24             [-1, 16, 3, 3]           2,304
#              ReLU-25             [-1, 16, 3, 3]               0
#       BatchNorm2d-26             [-1, 16, 3, 3]              32
#           Dropout-27             [-1, 16, 3, 3]               0
#         AvgPool2d-28             [-1, 16, 1, 1]               0
#            Linear-29                   [-1, 10]             170
# ================================================================
# Total params: 8,018
# Trainable params: 8,018
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.61
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.65
# ----------------------------------------------------------------

# %%
torch.manual_seed(1)
batch_size = 128

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
from tqdm import tqdm


def train(model, device, train_loader, optimizer, epoch, train_loss_graph, train_accuracy_graph):
    model.train()
    train_loss = 0
    correct = 0
    # pbar = tqdm(train_loader)
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)

        # HERE
        l1 = 0
        lambda_l1 = 0.01
        for p in model.parameters():
          l1 = l1 + p.abs().sum()
        loss = loss + lambda_l1 * l1

        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
        # pbar.set_description(desc= f'loss={loss.item()} batch_id={batch_idx}')
    train_loss /= len(train_loader.dataset)
    accuracy = 100. * correct / len(train_loader.dataset)
    print('Train set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)'.format(
        train_loss, correct, len(train_loader.dataset), accuracy
        ))
    
    train_loss_graph.append(train_loss)
    train_accuracy_graph.append(accuracy)
    return train_loss_graph, train_accuracy_graph, accuracy

incorrect_examples = []
def test(model, device, test_loader, test_loss_graph, test_accuracy_graph):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            
            # print(output.shape, target.shape)
            # _, pred = torch.max(output,1)
            # idxs_mask = ((pred == target) == False).nonzero()
            # incorrect_examples.append((data[idxs_mask].cpu()).numpy())

            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),accuracy
        ))
    test_loss_graph.append(test_loss)
    test_accuracy_graph.append(accuracy)
    return test_loss_graph, test_accuracy_graph

# %%
# from torch.optim.lr_scheduler import StepLR
from torch.optim.lr_scheduler import ReduceLROnPlateau

model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# scheduler = StepLR(optimizer, step_size=10, gamma=0.1)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=0, verbose=True)

train_loss_graph = []
train_accuracy_graph = []
test_loss_graph = []
test_accuracy_graph = []
for epoch in range(1, 16):
    print('epoch number ', epoch)
    train_loss_graph, train_accuracy_graph, accuracy = train(model, device, train_loader, optimizer, epoch, train_loss_graph, train_accuracy_graph)
    scheduler.step(accuracy)
    test_loss_graph, test_accuracy_graph = test(model, device, test_loader, test_loss_graph, test_accuracy_graph)

import matplotlib.pyplot as plt

# print(train_loss_graph, test_loss_graph)
# print(train_accuracy_graph, test_accuracy_graph)
# plt.figure(figsize=(10,5))
# plt.title("Training and Test Loss")
# plt.plot(train_loss_graph,label="train_loss")
# plt.plot(test_loss_graph,label="test_loss")
# plt.xlabel("iterations")
# plt.ylabel("Loss")
# plt.legend()
# plt.show()

# plt.figure(figsize=(10,5))
# plt.title("Training and Test Accuracy")
# plt.plot(train_accuracy_graph,label="train_accuracy")
# plt.plot(test_accuracy_graph,label="test_accuracy")
# plt.xlabel("iterations")
# plt.ylabel("Accuracy")
# plt.legend()
# plt.show()
# Out:
# epoch number  1
# Train set: Average loss: 0.0185, Accuracy: 53452/60000 (89.09%)
# Test set: Average loss: 0.8469, Accuracy: 7455/10000 (74.55%)
#
# epoch number  2
# Train set: Average loss: 0.0112, Accuracy: 56479/60000 (94.13%)
# Test set: Average loss: 0.4399, Accuracy: 8886/10000 (88.86%)
#
# epoch number  3
# Train set: Average loss: 0.0089, Accuracy: 56378/60000 (93.96%)
# Epoch     3: reducing learning rate of group 0 to 1.0000e-03.
# Test set: Average loss: 0.4142, Accuracy: 8847/10000 (88.47%)
#
# epoch number  4
# Train set: Average loss: 0.0064, Accuracy: 58159/60000 (96.93%)
# Test set: Average loss: 0.1701, Accuracy: 9624/10000 (96.24%)
#
# epoch number  5
# Train set: Average loss: 0.0060, Accuracy: 58044/60000 (96.74%)
# Epoch     5: reducing learning rate of group 0 to 1.0000e-04.
# Test set: Average loss: 0.1447, Accuracy: 9650/10000 (96.50%)
#
# epoch number  6
# Train set: Average loss: 0.0055, Accuracy: 58617/60000 (97.69%)
# Test set: Average loss: 0.0867, Accuracy: 9841/10000 (98.41%)
#
# epoch number  7
# Train set: Average loss: 0.0054, Accuracy: 58672/60000 (97.79%)
# Test set: Average loss: 0.0863, Accuracy: 9839/10000 (98.39%)
#
# epoch number  8
# Train set: Average loss: 0.0053, Accuracy: 58579/60000 (97.63%)
# Epoch     8: reducing learning rate of group 0 to 1.0000e-05.
# Test set: Average loss: 0.0851, Accuracy: 9850/10000 (98.50%)
#
# epoch number  9
# Train set: Average loss: 0.0052, Accuracy: 58752/60000 (97.92%)
# Test set: Average loss: 0.0834, Accuracy: 9854/10000 (98.54%)
#
# epoch number  10
# Train set: Average loss: 0.0052, Accuracy: 58761/60000 (97.94%)
# Test set: Average loss: 0.0871, Accuracy: 9844/10000 (98.44%)
#
# epoch number  11
# Train set: Average loss: 0.0052, Accuracy: 58740/60000 (97.90%)
# Epoch    11: reducing learning rate of group 0 to 1.0000e-06.
# Test set: Average loss: 0.0854, Accuracy: 9832/10000 (98.32%)
#
# epoch number  12
# Train set: Average loss: 0.0052, Accuracy: 58758/60000 (97.93%)
# Epoch    12: reducing learning rate of group 0 to 1.0000e-07.
# Test set: Average loss: 0.0843, Accuracy: 9846/10000 (98.46%)
#
# epoch number  13
# Train set: Average loss: 0.0052, Accuracy: 58790/60000 (97.98%)
# Test set: Average loss: 0.0818, Accuracy: 9848/10000 (98.48%)
#
# epoch number  14
# Train set: Average loss: 0.0052, Accuracy: 58758/60000 (97.93%)
# Epoch    14: reducing learning rate of group 0 to 1.0000e-08.
# Test set: Average loss: 0.0841, Accuracy: 9843/10000 (98.43%)
#
# epoch number  15
# Train set: Average loss: 0.0052, Accuracy: 58737/60000 (97.89%)
# Test set: Average loss: 0.0819, Accuracy: 9848/10000 (98.48%)

# %%
# fig = plt.figure(figsize=(20, 8))

# import numpy as np
# import matplotlib.pyplot as plt

# for idx in np.arange(10):
#   ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[])
#   img = incorrect_examples[idx][idx]
#   img = img/2 + 0.5
#   img = np.clip(img, 0, 1)
#   plt.imshow(img)
