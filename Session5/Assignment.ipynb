# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms


import warnings
warnings.filterwarnings("ignore")

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        drop_out_val = 0.01 # 0.05
        self.convblock1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=8, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(8),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28, rc-3

        self.convblock2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=8, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(8),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28, rc-5

        self.pool1 = nn.MaxPool2d(2, 2) # output_size = 12

        self.convblock3 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28

        self.convblock4 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=16, kernel_size=(3, 3), padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 28

        self.pool2 = nn.MaxPool2d(2, 2) # output_size = 14
        self.convblock100 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=8, kernel_size=(1, 1), padding=0, bias=False),
            # nn.ReLU(),
            # nn.Dropout(p=drop_out_val)
        ) # output_size = 14

        self.convblock5 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3, 3), padding=0, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 12

        self.convblock6 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=16, kernel_size=(3, 3), padding=0, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(p=drop_out_val)
        ) # output_size = 10

        self.convblock7 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=10, kernel_size=(3, 3), padding=0, bias=False),
        ) # output_size = 8
        self.gap = nn.Sequential(nn.AvgPool2d(3)) # output_size = 1


    def forward(self, x):
        # Adding drop out reduces the accuracy a bit
        x = self.convblock1(x)
        x = self.convblock2(x)
        x = self.pool1(x)
        x = self.convblock3(x)
        x = self.convblock4(x)
        x = self.pool2(x)
        x = self.convblock100(x)
        x = self.convblock5(x)
        x = self.convblock6(x)
        # x = self.convblock7(x)
        x = self.gap(x)
        # print(x.shape)
        x = x.view(x.size(0), -1)
        # print(x.shape)
        return F.log_softmax(x)

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net().to(device)
summary(model, input_size=(1, 28, 28))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              72
#               ReLU-2            [-1, 8, 28, 28]               0
#        BatchNorm2d-3            [-1, 8, 28, 28]              16
#            Dropout-4            [-1, 8, 28, 28]               0
#             Conv2d-5            [-1, 8, 28, 28]             576
#               ReLU-6            [-1, 8, 28, 28]               0
#        BatchNorm2d-7            [-1, 8, 28, 28]              16
#            Dropout-8            [-1, 8, 28, 28]               0
#          MaxPool2d-9            [-1, 8, 14, 14]               0
#            Conv2d-10           [-1, 16, 14, 14]           1,152
#              ReLU-11           [-1, 16, 14, 14]               0
#       BatchNorm2d-12           [-1, 16, 14, 14]              32
#           Dropout-13           [-1, 16, 14, 14]               0
#            Conv2d-14           [-1, 16, 14, 14]           2,304
#              ReLU-15           [-1, 16, 14, 14]               0
#       BatchNorm2d-16           [-1, 16, 14, 14]              32
#           Dropout-17           [-1, 16, 14, 14]               0
#         MaxPool2d-18             [-1, 16, 7, 7]               0
#            Conv2d-19              [-1, 8, 7, 7]             128
#            Conv2d-20             [-1, 16, 5, 5]           1,152
#              ReLU-21             [-1, 16, 5, 5]               0
#       BatchNorm2d-22             [-1, 16, 5, 5]              32
#           Dropout-23             [-1, 16, 5, 5]               0
#            Conv2d-24             [-1, 16, 3, 3]           2,304
#              ReLU-25             [-1, 16, 3, 3]               0
#       BatchNorm2d-26             [-1, 16, 3, 3]              32
#           Dropout-27             [-1, 16, 3, 3]               0
#         AvgPool2d-28             [-1, 16, 1, 1]               0
# ================================================================
# Total params: 7,848
# Trainable params: 7,848
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.61
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.64
# ----------------------------------------------------------------

# %%
torch.manual_seed(1)
batch_size = 128

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
from tqdm import tqdm


def train(model, device, train_loader, optimizer, epoch, train_loss_graph, train_accuracy_graph):
    model.train()
    train_loss = 0
    correct = 0
    # pbar = tqdm(train_loader)
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
        # pbar.set_description(desc= f'loss={loss.item()} batch_id={batch_idx}')
    train_loss /= len(train_loader.dataset)
    accuracy = 100. * correct / len(train_loader.dataset)
    print('Train set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)'.format(
        train_loss, correct, len(train_loader.dataset), accuracy
        ))
    
    train_loss_graph.append(train_loss)
    train_accuracy_graph.append(accuracy)
    return train_loss_graph, train_accuracy_graph


def test(model, device, test_loader, test_loss_graph, test_accuracy_graph):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),accuracy
        ))
    test_loss_graph.append(test_loss)
    test_accuracy_graph.append(accuracy)
    return test_loss_graph, test_accuracy_graph

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

train_loss_graph = []
train_accuracy_graph = []
test_loss_graph = []
test_accuracy_graph = []
for epoch in range(1, 16):
    print('epoch number ', epoch)
    train_loss_graph, train_accuracy_graph = train(model, device, train_loader, optimizer, epoch, train_loss_graph, train_accuracy_graph)
    test_loss_graph, test_accuracy_graph = test(model, device, test_loader, test_loss_graph, test_accuracy_graph)


import matplotlib.pyplot as plt

print(train_loss_graph, test_loss_graph)
print(train_accuracy_graph, test_accuracy_graph)
plt.figure(figsize=(10,5))
plt.title("Training and Test Loss")
plt.plot(train_loss_graph,label="train_loss")
plt.plot(test_loss_graph,label="test_loss")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.title("Training and Test Accuracy")
plt.plot(train_accuracy_graph,label="train_accuracy")
plt.plot(test_accuracy_graph,label="test_accuracy")
plt.xlabel("iterations")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# epoch number  1
# Train set: Average loss: 0.0027, Accuracy: 56512/60000 (94.19%)
# Test set: Average loss: 0.0923, Accuracy: 9824/10000 (98.24%)
#
# epoch number  2
# Train set: Average loss: 0.0007, Accuracy: 58884/60000 (98.14%)
# Test set: Average loss: 0.0648, Accuracy: 9857/10000 (98.57%)
#
# epoch number  3
# Train set: Average loss: 0.0005, Accuracy: 59116/60000 (98.53%)
# Test set: Average loss: 0.0494, Accuracy: 9884/10000 (98.84%)
#
# epoch number  4
# Train set: Average loss: 0.0004, Accuracy: 59221/60000 (98.70%)
# Test set: Average loss: 0.0463, Accuracy: 9881/10000 (98.81%)
#
# epoch number  5
# Train set: Average loss: 0.0003, Accuracy: 59383/60000 (98.97%)
# Test set: Average loss: 0.0318, Accuracy: 9921/10000 (99.21%)
#
# epoch number  6
# Train set: Average loss: 0.0003, Accuracy: 59382/60000 (98.97%)
# Test set: Average loss: 0.0294, Accuracy: 9920/10000 (99.20%)
#
# epoch number  7
# Train set: Average loss: 0.0003, Accuracy: 59464/60000 (99.11%)
# Test set: Average loss: 0.0289, Accuracy: 9924/10000 (99.24%)
#
# epoch number  8
# Train set: Average loss: 0.0003, Accuracy: 59495/60000 (99.16%)
# Test set: Average loss: 0.0272, Accuracy: 9921/10000 (99.21%)
#
# epoch number  9
# Train set: Average loss: 0.0002, Accuracy: 59496/60000 (99.16%)
# Test set: Average loss: 0.0277, Accuracy: 9923/10000 (99.23%)
#
# epoch number  10
# Train set: Average loss: 0.0002, Accuracy: 59552/60000 (99.25%)
# Test set: Average loss: 0.0255, Accuracy: 9933/10000 (99.33%)
#
# epoch number  11
# Train set: Average loss: 0.0002, Accuracy: 59632/60000 (99.39%)
# Test set: Average loss: 0.0244, Accuracy: 9934/10000 (99.34%)
#
# epoch number  12
# Train set: Average loss: 0.0002, Accuracy: 59626/60000 (99.38%)
# Test set: Average loss: 0.0251, Accuracy: 9936/10000 (99.36%)
#
# epoch number  13
# Train set: Average loss: 0.0002, Accuracy: 59598/60000 (99.33%)
# Test set: Average loss: 0.0230, Accuracy: 9932/10000 (99.32%)
#
# epoch number  14
# Train set: Average loss: 0.0002, Accuracy: 59619/60000 (99.36%)
# Test set: Average loss: 0.0223, Accuracy: 9929/10000 (99.29%)
#
# epoch number  15
# Train set: Average loss: 0.0002, Accuracy: 59660/60000 (99.43%)
# Test set: Average loss: 0.0233, Accuracy: 9938/10000 (99.38%)
